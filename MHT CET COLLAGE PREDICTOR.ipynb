# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
dts1=pd.read_csv(r"C:\Users\pawar\Downloads\kaggle_sw_errorfunc_descending_v01.csv")

# %%
dts1
# Out:
#           rank                                  branch  percentile  \
# 0        28379                  Mechanical Engineering   84.681193
# 1         4997  Electronics and Telecommunication Engg   90.095562
# 2        12535                  Mechanical Engineering   78.452705
# 3        23319                  Mechanical Engineering   87.434605
# 4        14007                       Civil Engineering   92.473577
# ...        ...                                     ...         ...
# 104340  120870                    Computer Engineering    3.350124
# 104341  119127                    Computer Engineering    6.377115
# 104342  117488                  Mechanical Engineering    8.758330
# 104343  119303                    Computer Engineering    5.903569
# 104344  122443  Electronics and Telecommunication Engg    0.428998
#
#         mean_percentile      error category seat_type  \
# 0             17.705766  66.975427     OPEN    GOPENH
# ...

# %%
dts1.isnull().sum()
# Out:
# rank                   0
# branch                 0
# percentile             0
# mean_percentile        0
# error                  0
# category               0
# seat_type              0
# college_name           0
# primary_seat_type      0
# secondary_seat_type    0
# score_type             0
# enrollment_no          0
# branch_code            0
# gender                 0
# fulfillment            0
# dtype: int64

# %%
a=dts1.value_counts("branch")
print()

# %%
plt.pie(a)
# Out:
# ([<matplotlib.patches.Wedge at 0x284720d8790>,
# ...
#  [Text(0.9299672646312389, 0.5875039461265698, ''),
#   Text(-0.014190829252975603, 1.0999084599934275, ''),
#   Text(-0.829843014170771, 0.7220530256372932, ''),
#   Text(-1.0996243908318193, 0.02874367909211811, ''),
#   Text(-0.9284252120979407, -0.589937814977896, ''),
#   Text(-0.5038623440850721, -0.9778152883919828, ''),
#   Text(-0.004653203179295079, -1.0999901580015035, ''),
#   Text(0.37315846938452657, -1.0347718380042035, ''),
#   Text(0.5611095714709906, -0.9461268671820083, ''),
#   Text(0.6619119833777398, -0.8785627617085457, ''),
#   Text(0.7283158178562373, -0.8243519087503833, ''),
#   Text(0.7824694988126245, -0.7731374285519492, ''),
#   Text(0.8270105585122075, -0.7252954819308658, ''),
#   Text(0.8662280980993502, -0.6779741013218593, ''),
#   Text(0.9019459621956999, -0.6296772834388051, ''),
#   Text(0.9304445047553236, -0.5867478364430676, ''),
#   Text(0.9516632600603389, -0.551667508061992, ''),
# ...

# %%
X=dts1.loc[:,["rank","percentile"]]
y=dts1.loc[:,["branch","college_name"]]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=51)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc= DecisionTreeClassifier()

# %%
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
a=int(input("Enter the your rank"))
b=a=int(input("Enter the your MHT CET Percentile"))

# %%
d=np.array([[a,b]])
type(d)
dtc.predict(d)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
lg=KNeighborsClassifier()

# %%
lg.fit(X_train,y_train)

# %%
a=int(input("Enter the your rank"))
b=a=int(input("Enter the your MHT CET Percentile"))

# %%
d=np.array([[a,b]])

# %%
s=lg.predict(d)[0]
s

# %%
print(f"Your Collage is predicted as {s[1]} and branch is {s[0]}")

# %%
bool(1)
